# %% [markdown]
# ### how to split by html header

# %%
from langchain_text_splitters import HTMLHeaderTextSplitter

# %%
html_string = """
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Basic HTML Profile</title>
</head>
<body>

    <!-- Main Heading -->
    <h1>Jane Doe</h1>

    <!-- Subheading and Paragraph -->
    <h2>About Me</h2>
    <p>Welcome to my sample webpage. I am a web developer based in Gujarat, India, and I enjoy building clean and responsive layouts.</p>

    <!-- Unordered List with data -->
    <h3>Quick Facts</h3>
    <h3>Contact Information</h3>
    <h3>Education</h3>
    <ul>
        <li><strong>Role:</strong> Frontend Developer</li>
        <li><strong>Location:</strong> Gujarat, India</li>
        <li><strong>Favorite Tech:</strong> HTML, CSS, JavaScript</li>
    </ul>

    <!-- Link -->
    <p>Check out more web resources on <a href="https://developer.mozilla.org" target="_blank">MDN Web Docs</a>.</p>

</body>
</html>

"""

# %%
header_to_split = [
    ("h1" ,"Header 1"),
    ("h2" ,"Header 2"),
    ("h3" ,"Header 3"),
    # ("li" ,"List Item")
]

# %%
html_splitter = HTMLHeaderTextSplitter(
       headers_to_split_on = header_to_split
    )

html_headers_splits = html_splitter.split_text(html_string)

# %%
html_headers_splits
# Out:
# [Document(metadata={}, page_content='Main Heading Subheading and Paragraph Unordered List with data Link'),
#  Document(metadata={'Header 1': 'Jane Doe'}, page_content='Jane Doe'),
#  Document(metadata={'Header 1': 'Jane Doe', 'Header 2': 'About Me'}, page_content='About Me'),
#  Document(metadata={'Header 1': 'Jane Doe', 'Header 2': 'About Me'}, page_content='Welcome to my sample webpage. I am a web developer based in Gujarat, India, and I enjoy building clean and responsive layouts.'),
#  Document(metadata={'Header 1': 'Jane Doe', 'Header 2': 'About Me', 'Header 3': 'Quick Facts'}, page_content='Quick Facts'),
#  Document(metadata={'Header 1': 'Jane Doe', 'Header 2': 'About Me', 'Header 3': 'Contact Information'}, page_content='Contact Information'),
#  Document(metadata={'Header 1': 'Jane Doe', 'Header 2': 'About Me', 'Header 3': 'Education'}, page_content='Education'),
# ...

# %%
url ="https://www.espncricinfo.com/story/will-virat-kohli-and-rohit-sharma-play-the-2027-world-cup-r-ashwin-says-why-not-1540429"
header_to_split = [
    ("h1" ,"Header 1"),
    ("h2" ,"Header 2"),
    ("h3" ,"Header 3"),
    # ("li" ,"List Item")
]

# %%
html_splitter = HTMLHeaderTextSplitter(
       headers_to_split_on = header_to_split
    )

html_headers_splits = html_splitter.split_text(url)
# Out:
# /home/atul/anaconda3/envs/genAi/lib/python3.14/site-packages/langchain_text_splitters/html.py:267: MarkupResemblesLocatorWarning: The input passed in on this line looks more like a URL than HTML or XML.
#
# If you meant to use Beautiful Soup to parse the web page found at a certain URL, then something has gone wrong. You should use an Python package like 'requests' to fetch the content behind the URL. Once you have the content as a string, you can feed that string into Beautiful Soup.
#
# However, if you want to parse some data that happens to look like a URL, then nothing has gone wrong: you are using Beautiful Soup correctly, and this warning is spurious and can be filtered. To make this warning go away, run this code before calling the BeautifulSoup constructor:
#
#     from bs4 import MarkupResemblesLocatorWarning
#     import warnings
#
#     warnings.filterwarnings("ignore", category=MarkupResemblesLocatorWarning)
#
#   soup = BeautifulSoup(html_content, "html.parser")

# %%
html_headers_splits
# Out:
# [Document(metadata={}, page_content='https://www.geeksforgeeks.org/')]
